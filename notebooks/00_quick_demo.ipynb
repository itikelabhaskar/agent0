# %% [markdown]
# # AgentX Quick Demo
#
# This notebook demonstrates the AgentX data quality agent.

# %%
# Import required libraries
import pandas as pd
import sys
sys.path.append('../')

# Load sample data
customers_df = pd.read_csv('../fake_data/customers_sample.csv')
holdings_df = pd.read_csv('../fake_data/holdings_sample.csv')

print("Customers data:")
customers_df.head()
